# %%
from openmsimodel.graph.open_graph import OpenGraph
from openmsimodel.graph.helpers import launch_graph_widget
from pathlib import Path

# %%
output = (Path().absolute().parent / "graphs")
open_graph = OpenGraph(name="AAE06_VAM-A_EDS_SRJT_Syn", 
    science_kit=None, 
    source="/srv/hemi01-j01/htmdec_models/data/birdshot/gemd_folder/AAE06_VAM-A", 
    output=output, 
    layout='visualisation',
    which='run')
G, relabeled_G, name_mapping = open_graph.build_graph(save=True)
# Out:
# -- Building runs of /srv/hemi01-j01/htmdec_models/data/birdshot/gemd_folder/AAE05_VAM-A
# Extracting folder...
# 0/81 gemd objects processed...
# 20/81 gemd objects processed...
# 40/81 gemd objects processed...
# 60/81 gemd objects processed...
# 80/81 gemd objects processed...
# Done.
# Relabeling nodes ...
# Saving graphs...
# Couldn't find GraphViz graph. Can't dump SVG and DOT files.
# Dumping graphml...
# Time elapsed: 0.002645254135131836
# -- Saved graph to /srv/hemi01-j01/htmdec_models/src/graphs/AAE05_VAM-A_EDS_SRJT_Syn_run.graphml
# -- Analysis --
# cycles in the graph: []
# disregarded/total number of gemd objects: 0/81
# number of connected components: 30
# total nb of isolates in the graph: 0

# %%
launch_graph_widget(G, engine='yfiles')
# Out:
# Launching widget for DiGraph named 'AAE05_VAM-A_EDS_SRJT_Syn' with 30 nodes and 28 edges
# GraphWidget(layout=Layout(height='800px', width='100%'))
