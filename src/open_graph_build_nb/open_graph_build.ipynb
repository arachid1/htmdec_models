# %%
from openmsimodel.graph.open_graph import OpenGraph
from openmsimodel.graph.helpers import launch_graph_widget
from pathlib import Path
# Out:
# /srv/hemi01-j01/anaconda3/envs/default/lib/python3.9/site-packages/dask/array/chunk_types.py:131: UserWarning: A NumPy version >=1.22.4 and <2.3.0 is required for this version of SciPy (detected version 1.21.0)
#   import scipy.sparse

# %%
output = str(Path().absolute() / "output")
open_graph = OpenGraph(name="birdshot", 
    science_kit=None, 
    source="../../data/birdshot/gemd_folder", 
    output=output, 
    layout='visualisation',
    which='run')
G, relabeled_G, name_mapping = open_graph.build_graph(save=True)
# Out:
# -- Building runs of ../../data/birdshot/gemd_folder
# Extracting folder...
# 0/123 gemd objects processed...
# 30/123 gemd objects processed...
# 60/123 gemd objects processed...
# 90/123 gemd objects processed...
# 120/123 gemd objects processed...
# Done.
# Relabeling nodes ...
# Saving graphs...
# Couldn't find GraphViz graph. Can't dump SVG and DOT files.
# Dumping graphml...
# Time elapsed: 0.2625620365142822
# -- Saved graph to /srv/hemi01-j01/htmdec_models/src/open_graph_build_nb/output/birdshot_run.graphml
# -- Analysis --
# cycles in the graph: []
# disregarded/total number of gemd objects: 0/123
# number of connected components: 51
# total nb of isolates in the graph: 0

# %%
launch_graph_widget(G, engine='yfiles')
# Out:
# Launching widget for DiGraph named 'birdshot' with 51 nodes and 48 edges
# GraphWidget(layout=Layout(height='800px', width='100%'))
