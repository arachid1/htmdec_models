# %%
from openmsimodel.graph.open_graph import OpenGraph
from openmsimodel.graph.helpers import launch_graph_widget
from pathlib import Path

# %%
output = (Path().absolute().parent.parent / "data" / "graphml_files")
open_graph = OpenGraph(name="v0_1_1-BBA_iteration", 
    science_kit=None, 
    source="/srv/hemi01-j01/htmdec_models/data/birdshot/gemd_folder/post_process/BBA", 
    output=output, 
    layout='visualisation',
    which='run')
G, relabeled_G, name_mapping = open_graph.build_graph(save=True)
# Out:
# -- Building runs of /srv/hemi01-j01/htmdec_models/data/birdshot/gemd_folder/post_process/BBA
# Extracting folder...
# 0/1301 gemd objects processed...
# 325/1301 gemd objects processed...
# 650/1301 gemd objects processed...
# 975/1301 gemd objects processed...
# 1300/1301 gemd objects processed...
# Done.
# Relabeling nodes ...
# Saving graphs...
# Couldn't find GraphViz graph. Can't dump SVG and DOT files.
# Dumping graphml...
# Time elapsed: 0.032102346420288086
# -- Saved graph to /srv/hemi01-j01/htmdec_models/data/graphml_files/v0_1_1-BBA_iteration-run.graphml
# -- Analysis --
# cycles in the graph: []
# disregarded/total number of gemd objects: 0/1301
# number of connected components: 487
# total nb of isolates in the graph: 0

# %%
launch_graph_widget(G, engine='yfiles')
# Out:
# Launching widget for DiGraph named 'v0_1_1-BBA_iteration' with 487 nodes and 486 edges
# GraphWidget(layout=Layout(height='800px', width='100%'))
