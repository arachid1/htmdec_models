# %%
from openmsimodel.graph.open_graph import OpenGraph
from openmsimodel.graph.helpers import launch_graph_widget
from pathlib import Path

# %%
output = (Path().absolute().parent / "graphs")
open_graph = OpenGraph(name="BBA08_VAM-A_EDS_NIHSR_SYN", 
    science_kit=None, 
    source="/srv/hemi01-j01/htmdec_models/data/birdshot/gemd_folder/BBA08_VAM-A", 
    output=output, 
    layout='visualisation',
    which='run')
G, relabeled_G, name_mapping = open_graph.build_graph(save=True)
# Out:
# -- Building runs of /srv/hemi01-j01/htmdec_models/data/birdshot/gemd_folder/BBC12_VAM-A/NI-HSR
# Extracting folder...
# 0/13 gemd objects processed...
# 3/13 gemd objects processed...
# 6/13 gemd objects processed...
# 9/13 gemd objects processed...
# 12/13 gemd objects processed...
# Done.
# Relabeling nodes ...
# Saving graphs...
# Couldn't find GraphViz graph. Can't dump SVG and DOT files.
# Dumping graphml...
# Time elapsed: 0.0019147396087646484
# -- Saved graph to /srv/hemi01-j01/htmdec_models/src/graphs/BBC12_VAM-A_NI-HSR_run.graphml
# -- Analysis --
# cycles in the graph: []
# disregarded/total number of gemd objects: 0/13
# number of connected components: 5
# total nb of isolates in the graph: 0

# %%
launch_graph_widget(G, engine='yfiles')
# Out:
# Launching widget for DiGraph named 'BBC12_VAM-A_NI-HSR' with 5 nodes and 4 edges
# GraphWidget(layout=Layout(height='500px', width='100%'))
