# %%
# %env
from openmsimodel.llm.openmsi_llm import OpenMSI_LLM
import os
from pathlib import Path
from openmsimodel.graph.open_graph import OpenGraph

# %%
from dotenv import load_dotenv
load_dotenv(dotenv_path='/home/arachid1/vars.env')

OPENAI_KEY = os.getenv('OPENAI_KEY')

openmsi_llm = OpenMSI_LLM(OPENAI_KEY)
target_folder = Path().absolute() / "output"

# %%
graph = openmsi_llm.load_graphml("../graphs/birdshot_run_0306.graphml")

# %%
subgraphs = OpenGraph.get_isolated_subgraphs(graph)
selected_subgraphs = sorted(subgraphs, key=lambda sg: sg.number_of_nodes())[-15:]
# OpenGraph.save_subgraphs(selected_subgraphs, 'test')

# %%
sentences = []
for subgraph in selected_subgraphs:
    sentences.append(" ".join(openmsi_llm.graph_to_sentences(subgraph)))
context = openmsi_llm.build_context(sentences)
print(len(context))
# Out:
# 62841

# %%
answer = openmsi_llm.ask_question_with_context(context[:4097], "are there proportional relationships between properties/conditions/parameters values?")
print(answer)
# Out:
# It is possible that there are proportional relationships between properties/conditions/parameters values in this experiment, however, without further information or analysis it is difficult to determine for certain. Some values, such as temperature and pressure, may have a direct proportional relationship, while others, such as material composition, may have a more complex relationship that cannot be determined without additional context. It would be best to consult the experiment data or perform further analysis to definitively determine whether there are proportional relationships between these properties.
